# %% [markdown]
# <a href="https://colab.research.google.com/github/oseghr/MachineLearning/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load neccessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Basic Graph
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,10]
plt.plot(x,y)
plt.title('First Graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
